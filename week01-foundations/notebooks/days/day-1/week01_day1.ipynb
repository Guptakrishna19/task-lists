# %% [markdown]
# ---
#
# ## Day 1 — Environment & Git Setup  ·  ⏱️ 5h
#
# **🎯 Objective:** Set up a professional dev environment and the Git workflow.
#
# **📖 Read:** Git Handbook; Python venv docs
#
# **💻 Exercises:**
# - Init a repo, make 5 commits on a branch, merge to main
# - Create and resolve a merge conflict on purpose
#
# **🛠️ Task:** Install pyenv/conda, create .venv, pip freeze > requirements.txt, write .gitignore, push scaffold to GitHub.
#
# **📦 Deliverable:** Public GitHub repo, first commit, README skeleton.

# %%
# Day 1 — exercises: Environment & Git Setup

# %%
# Day 1 — task: Install pyenv/conda, create .venv, pip freeze > requirements.txt, write .gitignore, push scaffold to GitHub.
