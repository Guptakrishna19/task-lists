# %% [markdown]
# ---
#
# ## Day 40 — RAG Basics  ·  ⏱️ 7h
#
# **🎯 Objective:** Ground LLM answers in your own documents.
#
# **📖 Read:** RAG concept guides (LangChain/LlamaIndex intro, or build raw)
#
# **💻 Exercises:**
# - chunking strategies, retrieval, context injection, source citation, empty-result fallback
#
# **🛠️ Task:** 'Chat with your docs' prototype: ingest -> embed -> retrieve -> LLM answers with cited sources.
#
# **📦 Deliverable:** rag_prototype notebook.

# %% [markdown]
# ### Detailed Task Plan
#
# Use this checklist to complete **Day 40 — RAG Basics  ·  ⏱️ 7h** confidently.
#
# **Step-by-step execution**
# - Start by restating the task in your own words and listing assumptions/data needed.
# - 1. Define scope and success criteria for: 'Chat with your docs' prototype: ingest -> embed -> retrieve -> LLM answers with cited sources.
# - 2. Implement the core solution for: 'Chat with your docs' prototype: ingest -> embed -> retrieve -> LLM answers with cited sources.
# - 3. Validate the result with test examples and edge cases for: 'Chat with your docs' prototype: ingest -> embed -> retrieve -> LLM answers with cited sources.
# - Run and verify each step before moving ahead; if something fails, document the fix briefly.
# - Add a short markdown reflection: what was difficult, what you improved, and what remains.
#
# **Expected output for this task**
# - rag_prototype notebook.
# - All outputs should be reproducible when running cells/scripts from start to finish.
#
# **Quality checks before marking complete**
# - Solution handles normal cases and at least 2 edge/error cases.
# - Code/analysis is organized, readable, and free of unused artifacts.
# - Final result is clearly visible and ready for mentor review.

# %% [markdown]
# ## Task Guide
#
# Use this guide to complete **Day 40 — RAG Basics  ·  ⏱️ 7h** without confusion.
#
# ### What you need to do
# 1. Read the day/week prompt fully before writing any code.
# 2. Complete the **Exercises** section first to practice the core concept.
# 3. Complete the **Task** section as a mini-deliverable (not just partial code).
# 4. Write short notes in markdown: what you tried, what failed, and what worked.
# 5. Validate outputs (prints/charts/files) and clean up your final code cells.
#
# ### Definition of done
# - All exercise prompts have working solutions.
# - The main task runs end-to-end without errors.
# - Results are visible (table/plot/file/model metrics depending on day).
# - Code is readable: meaningful names, comments only where needed, no dead code.
# - Notebook is clean: cells run in order from top to bottom.
#
# ### What to submit
# - Completed notebook with final outputs saved.
# - Any required project files/scripts referenced in the task prompt.
# - A brief self-review note (2-5 bullets) at the end: learnings and blockers.

# %%
# Day 40 — exercises: RAG Basics

# %%
# Day 40 — task: 'Chat with your docs' prototype: ingest -> embed -> retrieve -> LLM answers with cited sources.
